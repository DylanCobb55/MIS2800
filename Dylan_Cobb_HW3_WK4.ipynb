# %% [markdown]
# <a href="https://colab.research.google.com/github/DylanCobb55/MIS2800/blob/main/Dylan_Cobb_HW3_WK4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# To Complete for Credit
# 1. Fix the errors in the 10 blocks that have an error. A brief comment has been added to each one to provide guidance on what is
# missing.
# 2. Answer the questions at the end on how you fixed the errors.
# 3. Save file into GitHub and submit the GitHub link into ISMS.

# %% [markdown]
# The next six blocks provide the exact code to run to get your Colab file started to run SQLite3

# %%
# Type this code exactly as shown to intall the first library needed for SQLite3 to work using SQLite Magic
# !pip install --upgrade pandas ipython-sql prettytable==3.10.1

# %%
# Install the SQL extension. Remember to type exactly as shown here.
# !pip install ipython-sql
print("ipython sql installed")
# Out:
# ...
# ipython sql installed

# %%
# Load the SQL magic extension
# %load_ext sql

# %%
#this code imports sqlite3 and prints a statement stating it has been imported
import sqlite3
print("sqlite3 imported")
# Out:
# sqlite3 imported

# %%
# This creates a brand-new, empty database file named 'AdCampaigns2026.db'
conn = sqlite3.connect('AdCampaigns2026.db')
print("database created")
# Out:
# database created

# %%
# This line is required so Colab stops acting like Python and acts more like a SQL database terminal
# %sql sqlite:///AdCampaigns2026.db

# %% [markdown]
# There are bugs (mistakes) for you to find and fix in the next 10 blocks

# %%
# %%sql
# CREATE TABLE Marketing_Brands (
#   brand_id INTEGER PRIMARY KEY,
#   brand_name TEXT,
#   brand_type TEXT,
#   brand_budget INTEGER
# ) STRICT;
# Out:
#  * sqlite:///AdCampaigns2026.db
# Done.
# []

# %%
# %%sql
# INSERT INTO Marketing_Brands (brand_id, brand_name, brand_type, brand_budget)
# VALUES
#   (1, 'Doritos', 'Snacks', 7000000),
#   (2, 'AWS', 'Technology', 15000000),
#   (3, 'Pepsi', 'Beverages', 2000000),
#   (4, 'He_Gets_Us', 'Religious', 1000000),
#   (5, 'Dr_Pepper', 'Beverages', 5000000),
#   (6, 'IBM', 'Technology', 100000),
#   (7, 'Google', 'Technology', 80000000);
# Out:
#  * sqlite:///AdCampaigns2026.db
# 7 rows affected.
# []

# %%
# %%sql
# SELECT * FROM Marketing_Brands;
# Out:
#  * sqlite:///AdCampaigns2026.db
# Done.
# [(1, 'Doritos', 'Snacks', 7000000),
#  (2, 'AWS', 'Technology', 15000000),
#  (3, 'Pepsi', 'Beverages', 2000000),
#  (4, 'He_Gets_Us', 'Religious', 1000000),
#  (5, 'Dr_Pepper', 'Beverages', 5000000),
#  (6, 'IBM', 'Technology', 100000),
#  (7, 'Google', 'Technology', 80000000)]

# %%
# %%sql
# SELECT brand_name, brand_type FROM Marketing_Brands WHERE brand_budget > 700000;
# Out:
#  * sqlite:///AdCampaigns2026.db
# Done.
# [('Doritos', 'Snacks'),
#  ('AWS', 'Technology'),
#  ('Pepsi', 'Beverages'),
#  ('He_Gets_Us', 'Religious'),
#  ('Dr_Pepper', 'Beverages'),
#  ('Google', 'Technology')]

# %%
# %%sql
# SELECT brand_type FROM Marketing_Brands WHERE brand_type = 'Religious';
# Out:
#  * sqlite:///AdCampaigns2026.db
# Done.
# [('Religious',)]

# %%
# %%sql
# SELECT brand_name FROM Marketing_Brands WHERE brand_budget < 1000000;
# Out:
#  * sqlite:///AdCampaigns2026.db
# Done.
# [('IBM',)]

# %%
# %%sql
# SELECT * FROM Marketing_Brands WHERE brand_budget > 7000000
# Out:
#  * sqlite:///AdCampaigns2026.db
# Done.
# [(2, 'AWS', 'Technology', 15000000), (7, 'Google', 'Technology', 80000000)]

# %%
# %%sql
# SELECT brand_name FROM Marketing_Brands WHERE brand_type = 'Snacks' OR brand_type = 'Beverages';
# Out:
#  * sqlite:///AdCampaigns2026.db
# Done.
# [('Doritos',), ('Pepsi',), ('Dr_Pepper',)]

# %%
# %%sql
# SELECT brand_name, brand_budget FROM Marketing_Brands ORDER BY brand_budget DESC;
# Out:
#  * sqlite:///AdCampaigns2026.db
# Done.
# [('Google', 80000000),
#  ('AWS', 15000000),
#  ('Doritos', 7000000),
#  ('Dr_Pepper', 5000000),
#  ('Pepsi', 2000000),
#  ('He_Gets_Us', 1000000),
#  ('IBM', 100000)]

# %%
# %%sql
# SELECT * FROM Marketing_Brands ORDER BY brand_budget ASC;
# Out:
#  * sqlite:///AdCampaigns2026.db
# Done.
# [(6, 'IBM', 'Technology', 100000),
#  (4, 'He_Gets_Us', 'Religious', 1000000),
#  (3, 'Pepsi', 'Beverages', 2000000),
#  (5, 'Dr_Pepper', 'Beverages', 5000000),
#  (1, 'Doritos', 'Snacks', 7000000),
#  (2, 'AWS', 'Technology', 15000000),
#  (7, 'Google', 'Technology', 80000000)]

# %% [markdown]
# Answer the Questions Below Based on the SQL Code You've Run Above

# %% [markdown]
# 1. How did you fix the error in Block #1? Answer:  **The word table was missing from the CREATE TABLE**
# 2. How did you fix the error in Block #2? Answer: **The word into was missing from INSERT INTO and the last google entry was only 80 so that was changed as well.**
# 3. How did you fix the error in Block #3? Answer: **The * was missing after SELECT.**
# 4. How did you fix the error in Block #4? Answer:T**he SELECT statement was modified to include specific columns and the WHERE clause was added to filter by brand_budget > 700000.**
# 5. How did you fix the error in Block #5? Answer:**The SELECT statement was modified to include brand_type and a WHERE clause was added to filter for brand_type = 'Religious'.**
# 6. How did you fix the error in Block #6? Answer: **The SELECT statement was modified to include brand_name and a WHERE clause was added to filter for brand_budget < 1000000.**
# 7. How did you fix the error in Block #7? Answer: **The command %%sql was missing at the beginning of the cell, which was added to enable direct SQL execution.**
#
#
# 8. How did you fix the error in Block #8? Answer:**The SELECT statement was adjusted to show brand_name and a WHERE clause was added to filter for 'Snacks' or 'Beverages' brand types.**
# 9. How did you fix the error in Block #9? Answer:**It was fixed by specifying brand_name and brand_budget in the SELECT clause and adding ORDER BY brand_budget DESC for sorting.**
# 10. How did you fix the error in Block #10? Answer:**The query was completed to SELECT * FROM Marketing_Brands ORDER BY brand_budget ASC to display all columns sorted by budget in ascending order. **
